# %%
from googleapiclient.discovery import build # for using api to send requests
import pandas as pd

# %%
KEY = "AIzaSyBT3GkJ8WUvdum1PGd3aFAXHc3eXgs19Sg"
youtube = build('youtube','v3',developerKey=KEY)

# %%
channel_ids = [
    "UCFy846QdKs3LbLgBpSqPcdg", # The Kiffness
    "UCeVMnSShP_Iviwkknt83cww", # Code with harry
    "UC0rE2qq81of4fojo-KhO5rg", # Tanmay bhatt
    "UC9CYT9gSNLevX5ey2_6CK0Q", # NDTV
    "CSHZKyawb77ixDdsGog4iWA",  # Lex Fridman
]

# %%
def getChannelStats(yoututbe,channel_ids):
  all_data = []
  request = youtube.channels().list(part='snippet,contentDetails,statistics',id=','.join(channel_ids))
  response = request.execute()
  # PreProcessing
  for i in range(len(response['items'])):
    data = dict(
        Channel_name = response['items'][i]['snippet']['title'],
        Subscribers = response['items'][i]['statistics']['subscriberCount'],
        Views = response['items'][i]['statistics']['viewCount'],
        Total_videos = response['items'][i]['statistics']['videoCount'],
        playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'],
        )
    all_data.append(data)

  return all_data

# %%
collected_data = getChannelStats(youtube,channel_ids)
collected_data
# Out:
# [{'Channel_name': 'The Kiffness',
#   'Subscribers': '2750000',
#   'Views': '630424013',
#   'Total_videos': '228',
#   'playlist_id': 'UUFy846QdKs3LbLgBpSqPcdg'},
#  {'Channel_name': 'CodeWithHarry',
#   'Subscribers': '6630000',
#   'Views': '832219337',
#   'Total_videos': '2396',
#   'playlist_id': 'UUeVMnSShP_Iviwkknt83cww'},
#  {'Channel_name': 'Tanmay Bhat',
#   'Subscribers': '4910000',
#   'Views': '1662253736',
#   'Total_videos': '1121',
#   'playlist_id': 'UU0rE2qq81of4fojo-KhO5rg'},
#  {'Channel_name': 'NDTV India',
#   'Subscribers': '17800000',
#   'Views': '8237846170',
#   'Total_videos': '130985',
#   'playlist_id': 'UU9CYT9gSNLevX5ey2_6CK0Q'}]

# %%
structured_form = pd.DataFrame(collected_data)
structured_form
# Out:
#     Channel_name Subscribers       Views Total_videos  \
# 0   The Kiffness     2750000   630424013          228
# 1  CodeWithHarry     6630000   832219337         2396
# 2    Tanmay Bhat     4910000  1662253736         1121
# 3     NDTV India    17800000  8237846170       130985
#
#                 playlist_id
# 0  UUFy846QdKs3LbLgBpSqPcdg
# 1  UUeVMnSShP_Iviwkknt83cww
# 2  UU0rE2qq81of4fojo-KhO5rg
# 3  UU9CYT9gSNLevX5ey2_6CK0Q

# %%
structured_form.to_csv("collected_yt_channels_data.csv")

# %%
channel_id = [
    "UCJIfeSCssxSC_Dhc5s7woww",  # lex clips
    "CYI_ychRnL7sJrG6PUSBpQA",   # cbn news
    "UCeVMnSShP_Iviwkknt83cww",  # code with harry
    "UC1bwliGvJogr7cWK0nT2Eag",  # mkiceandfire
    "UCchBatdUMZoMfJ3rIzgV84g",  # viva la dirt league
    "UCsooa4yRKGN_zEE8iknghZA"   # TED-ED
]

# %%
def get_channel_stats(youtube, channel_id):
    all_data = []
    request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id=','.join(channel_id))
    response = request.execute()
    for i in range(len(response['items'])):
        data = {
            'Channel_name': response['items'][i]['snippet']['title'],
            'Subscribers': response['items'][i]['statistics']['subscriberCount'],
            'Views': response['items'][i]['statistics']['viewCount'],
            'Total_videos': response['items'][i]['statistics']['videoCount'],
            'playlist_id': response['items'][i]['contentDetails']['relatedPlaylists']['uploads']
        }
        all_data.append(data)
    return all_data

# %%
allchannestats = get_channel_stats(youtube, channel_id)
channel_data = pd.DataFrame(allchannestats)

# %%
channel_data
# Out:
#           Channel_name Subscribers       Views Total_videos  \
# 0            Lex Clips     1330000   456779441         7183
# 1               TED-Ed    20300000  4031213941         2191
# 2         MKIceAndFire     3970000  2288499220         7568
# 3        CodeWithHarry     6630000   832219337         2396
# 4  Viva La Dirt League     6650000  4063538478         2265
#
#                 playlist_id
# 0  UUJIfeSCssxSC_Dhc5s7woww
# 1  UUsooa4yRKGN_zEE8iknghZA
# 2  UU1bwliGvJogr7cWK0nT2Eag
# 3  UUeVMnSShP_Iviwkknt83cww
# 4  UUchBatdUMZoMfJ3rIzgV84g

# %%
channel_data['Subscribers'] = pd.to_numeric(channel_data['Subscribers'])
channel_data['Views'] = pd.to_numeric(channel_data['Views'])
channel_data['Total_videos'] = pd.to_numeric(channel_data['Total_videos'])
channel_data.dtypes
# Out:
# Channel_name    object
# Subscribers      int64
# Views            int64
# Total_videos     int64
# playlist_id     object
# dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-d09817f31727> in <cell line: 2>()
#       1 plt.figure(figsize=(12, 6))
# ----> 2 sns.scatterplot(data=channel_data, x='Subscribers', y='Views', hue='Channel_name')
#       3 plt.title('Subscribers vs. Views')
#       4 plt.xlabel('Subscribers')
#       5 plt.ylabel('Views')
#
# NameError: name 'sns' is not defined

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=channel_data, x='Subscribers', y='Views', hue='Channel_name')
plt.title('Subscribers vs. Views')
plt.xlabel('Subscribers')
plt.ylabel('Views')
plt.xscale('log')
plt.yscale('log')
plt.legend(title='Channel Name')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='Channel_name', y='Total_videos', data=channel_data)
plt.title('Number of Videos per Channel')
plt.xlabel('Channel Name')
plt.ylabel('Total Videos')
plt.xticks(rotation=45)
plt.show()

# %%
sns.set(rc={'figure.figsize':(10,8)})
ax = sns.barplot(x='Channel_name', y='Subscribers', data=channel_data)
plt.title('Subscribers Count by Channel')
plt.xlabel('Channel Name')
plt.ylabel('Subscribers')
plt.xticks(rotation=45)
plt.show()

# %%
ax = sns.barplot(x='Channel_name', y='Views', data=channel_data)
plt.title('Views Count by Channel')
plt.xlabel('Channel Name')
plt.ylabel('Views')
plt.xticks(rotation=45)
plt.show()

# %%
ax = sns.barplot(x='Channel_name', y='Total_videos', data=channel_data)
plt.title('Total Videos Count by Channel')
plt.xlabel('Channel Name')
plt.ylabel('Total Videos')
plt.xticks(rotation=45)
plt.show()

# %%
def get_video_ids(youtube, playlist_id):
    request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId=playlist_id,
                maxResults=50)
    response = request.execute()

    video_ids = []

    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])

    next_page_token = response.get('nextPageToken')
    while next_page_token:
        request = youtube.playlistItems().list(
                    part='contentDetails',
                    playlistId=playlist_id,
                    maxResults=50,
                    pageToken=next_page_token)
        response = request.execute()
        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])
        next_page_token = response.get('nextPageToken')

    return video_ids

# %%
playlist_id = channel_data.loc[channel_data['Channel_name'] == 'MKIceAndFire', 'playlist_id'].iloc[0]
video_ids = get_video_ids(youtube, playlist_id)
print("For channel YouTube MKIceAndFire we have over ", len(video_ids), " video ids")
# Out:
# ['7xKrlBdZKZA', 'c5_IlLV_PBs', 'rZ-0xzkA8to', 'IYyCrR2-V9I', '92Mh3UXEMIE', 'eQyVUUK5oFE', 'GkfF_eFMpgQ', 'Gu66H5zmhkc', 'LBf7NyW5P1g', 'TszzRWQuZnU', 'WW6iGXA432E', '6FKLanyftuk', 'PJGoDUVxVqo', 'UfHD3P7lQvo', 'fifpBAkTmRA', 'Lvgb0rSWDQw', 'Pzqq88SH4E4', 'CAcD8TWAn4Y', 'ZFoPXEFr1yw', '6iIvnim-Xq0', 'T4DFKOlrXCQ', 'Bkt31zux_a0', 'cAPoq-lMEg4', 'FnTzfyH7xtU', '0K9I4K7031c', 'fiG9eVyQgU4', 'JJG-zNTy1Ms', 'ZtbBbH75qts', 'Ts1NHWTpsbo', 'drjq5Y1p3kc', 'bj5253_6TjA', 'JsttM_AFajo', '22oxQoEIUuk', 'JGKR5ebWBjI', 'QWoF8S_F3Bo', '4FYAtzJcUNs', 'kuNt5N94C1c', 'lJxjMDGKViU', '-fr9QtHZink', 'utTHz6jWdrs', 'orcc6nPlUyY', 'EX4o0QDGb94', '5aVZKQ30in4', '9N7v432t-ec', 'CvXuK56r_Aw', 'GXRCGC2Yvyw', 'CuTU_qOZRq4', 'NvHXxMVolg4', 'IujEATA3NGE', 'uKLJlluFjpA', 'vq4SB88nipY', 'o-c3NI7CMMo', 'H5ar-f0Yi0s', 'JTGJ4v-slkI', 'Mz_tkZLml4w', 'nePmPtEd-9w', 'dDF5h-gNfbs', 'dvzVNuSvdrM', 'gTQUV6qso-g', 'Fhxq19qbBCs', 'wLppyOIGMBk', '4DII3yLCL4A', 'IH1EiOSuLEM', 'ZvEztNhGdOM', 'RFNNktqjyEo', 'H3koeipzgz8', 'Q7gDZD7vnTs', 'jooxmi7Krr8', 'efKDPoib5CU', 'DYpUfXswVZo', 'jHb8mH-AwGk', 'dyTYqCYqwrA', 'UCxI3TdKqkY', 'osHALT6x49Y', 'pmeu14roi10', 'c0kfRU3EboA', 'vP4uTazAo6Q', 'NyVtTbspupM', 'B5unJCCZGzw', 'Q28Nx9QkSbU', 'o0bx8yq4moo', 'lD2O-ZlYf2I', 'Uur0_SmdRUU', 'oEbbEflIB6M', 'xfkFuJey9Ak', 'HoOweOgeyiI', 't1z6DBiUe-0', 'KG_OfFUyDfg', 'VbgbAqxfhSQ', '4HnNjlXCpGA', 'iT1ZRN0YRpY', 'EgetAHoPBKQ', 'hfON6ywYVwc', 'bg8i4CvE74M', 'UNoDcYgcLS4', 'Leb8_DXD7qM', 'TQh0BAkSqRg', '7p0_jK_tO4c', '-kpf-51W81o', 'nDMDMw4M_n0', 'LN0kCQ2cuCY', 'NHqg5osTtAg', '05zNatvdUVo', '6kKQMYIp5Cc', 'Jb7kVhb_iKg', 'M1Mi6hTKAQg', 'yqs-z2dOsrg', 'P3kiEHbL0lc', 'gRIR38HXKEY', 'JnIprXJMvN4', 'L0NcvmOG18Y', 'a09KInB3XQI', 'H6FwrKscQPQ', '1fg4Szpl
DTeLE9WGs', 'Iz9Dl2utjUU', 'q21SPEiKMNQ', 'pkXtGZauXfE', 'xv3wFGGeIsI', 'DxJDCDgmbM8', 'hT-LKGp-bMo', 'qM8TlyMWoDA', 'vEODQz9OYdM', 'Z4gdqBuh9fg', '44aUJ96kMww', 'wM3ESJ5i-JI', 'hhCAN35QHBU', 'JAGdWAhmjyU', 'FY2RuSAXgk0', '1b34UUj399M', 'k3wFOePw7C8', '5ASn8xH4hRg', 'Oo1-GlH17rg', 'X9nFrOKtK4M', '2zraxVfRxF8', 'HP1P9zDodqc', 'K6UA5KpoOUg', 'HDq3pRK07-4', 'KfKLdoUYHac', 'ffj69-a6r2k', 'K33itslmXvs', 'inMunP1MTnM', 'XMYcvBfooKM', '1Ftviehwx3Y', 'funVHnukv8M', '92TKFJCnREw', 'mH-wXUhV-GE', 'Bcz8jispk58', '-g1b3xPwTLg', 'Xec8U8xiSc8', 'CidrKkcNQro', 'LEFy6QTSqIU', 'pyKONWsQ1ek', 'gi1VqpSTGWM', 'G1ef08CGc2k', 'kvYZ23EoqwQ', 'DlfDXCE_ ...
# For channel YouTube MKIceAndFire we have over  7568  video ids

# %%
def get_video_details(youtube, video_ids):
    all_video_stats = []

    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
                    part='snippet,statistics',
                    id=','.join(video_ids[i:i+50]))
        response = request.execute()

        for video in response['items']:
            video_stats = {
                'Title': video['snippet']['title'],
                'Published_date': video['snippet']['publishedAt'],
                'Views': video['statistics']['viewCount'],
                'Likes': video['statistics']['likeCount'],
                'Comments': video['statistics']['commentCount'],
                'Favourites': video['statistics']['favoriteCount']
            }
            all_video_stats.append(video_stats)

    return all_video_stats

# %%
video_details = get_video_details(youtube, video_ids)
video_data = pd.DataFrame(video_details)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
video_data['Month'] = pd.to_datetime(video_data['Published_date']).dt.strftime('%b')
videos_per_month = video_data.groupby('Month', as_index=False).size()

sort_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun','Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
videos_per_month.index = pd.CategoricalIndex(videos_per_month['Month'], categories=sort_order, ordered=True)
videos_per_month = videos_per_month.sort_index()

ax2 = sns.barplot(x='Month', y='size', data=videos_per_month)
plt.title('Number of Videos Published per Month')
plt.xlabel('Month')
plt.ylabel('Number of Videos')
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-087947aec5b3> in <cell line: 1>()
# ----> 1 video_data['Month'] = pd.to_datetime(video_data['Published_date']).dt.strftime('%b')
#       2 videos_per_month = video_data.groupby('Month', as_index=False).size()
#       3
#       4 sort_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun','Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
#       5 videos_per_month.index = pd.CategoricalIndex(videos_per_month['Month'], categories=sort_order, ordered=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3891             if self.columns.nlevels > 1:
#    3892                 return self._getitem_multilevel(key)
# -> 3893             indexer = self.columns.get_loc(key)
#    3894             if is_integer(indexer):
#    3895                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/range.py in get_loc(self, key)
#     416                 raise KeyError(key) from err
#     417         if isinstance(key, Hashable):
# --> 418             raise KeyError(key)
#     419         self._check_indexing_error(key)
#     420         raise KeyError(key)
#
# KeyError: 'Published_date'

# %%
def get_video_details(youtube, video_ids):
    all_video_stats = []

    # Process video IDs in batches of 50
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part='snippet,statistics',
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute()

        for video in response['items']:
            # Use .get() to handle missing keys safely
            video_stats = {
                'Title': video['snippet']['title'],
                'Published_date': video['snippet'].get('publishedAt', 'N/A'),
                'Views': video['statistics'].get('viewCount', 'N/A'),
                'Likes': video['statistics'].get('likeCount', 'N/A'),
                'Comments': video['statistics'].get('commentCount', 'N/A'),
                'Favourites': video['statistics'].get('favoriteCount', 'N/A')
            }
            all_video_stats.append(video_stats)

    return all_video_stats

# Example usage
video_ids = get_video_ids(youtube, playlist_id)
video_details = get_video_details(youtube, video_ids)
video_data = pd.DataFrame(video_details)
print(video_data.head())
# Out:
UU', 'q21SPEiKMNQ', 'pkXtGZauXfE', 'xv3wFGGeIsI', 'DxJDCDgmbM8', 'hT-LKGp-bMo', 'qM8TlyMWoDA', 'vEODQz9OYdM', 'Z4gdqBuh9fg', '44aUJ96kMww', 'wM3ESJ5i-JI', 'hhCAN35QHBU', 'JAGdWAhmjyU', 'FY2RuSAXgk0', '1b34UUj399M', 'k3wFOePw7C8', '5ASn8xH4hRg', 'Oo1-GlH17rg', 'X9nFrOKtK4M', '2zraxVfRxF8', 'HP1P9zDodqc', 'K6UA5KpoOUg', 'HDq3pRK07-4', 'KfKLdoUYHac', 'ffj69-a6r2k', 'K33itslmXvs', 'inMunP1MTnM', 'XMYcvBfooKM', '1Ftviehwx3Y', 'funVHnukv8M', '92TKFJCnREw', 'mH-wXUhV-GE', 'Bcz8jispk58', '-g1b3xPwTLg', 'Xec8U8xiSc8', 'CidrKkcNQro', 'LEFy6QTSqIU', 'pyKONWsQ1ek', 'gi1VqpSTGWM', 'G1ef08CGc2k', 'kvYZ23EoqwQ', 'DlfDXCE_ ...
#                                                Title        Published_date  \
# 0  LOLLIPOP CHAINSAW REPOP Gameplay Walkthrough F...  2024-09-13T16:00:16Z
# 1  DEAD SPACE 2 Gameplay Walkthrough FULL GAME [4...  2024-09-12T19:03:11Z
# 2  SON AND BONE Gameplay Walkthrough FULL GAME [4...  2024-09-09T22:00:09Z
# 3  ASTRO BOT PS5 Gameplay Walkthrough FULL GAME 1...  2024-09-06T09:17:23Z
# 4  WARHAMMER 40K SPACE MARINE 2 Gameplay Walkthro...  2024-09-04T16:00:05Z
#
#     Views  Likes Comments Favourites
# 0   38335   1141      153          0
# 1   23371    859       52          0
# 2  125263   2450      274          0
# 3  231978   4042      422          0
# 4  742945  12549     1205          0

# %%
# Extract month from the 'Published_date'
video_data['Month'] = pd.to_datetime(video_data['Published_date']).dt.strftime('%b')

# Count number of videos per month
videos_per_month = video_data.groupby('Month', as_index=False).size()

# Define the desired order of months
sort_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun','Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
videos_per_month.index = pd.CategoricalIndex(videos_per_month['Month'], categories=sort_order, ordered=True)
videos_per_month = videos_per_month.sort_index()

# Plot the number of videos published per month
ax2 = sns.barplot(x='Month', y='size', data=videos_per_month)
plt.title('Number of Videos Published per Month')
plt.xlabel('Month')
plt.ylabel('Number of Videos')
plt.xticks(rotation=45)
plt.show()

# %%
# Save video data to a CSV file for further analysis
video_data.to_csv("mkiceandfire_video_stats.csv")

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# Load your data
video_data = pd.read_csv("mkiceandfire_video_stats.csv")

# Feature selection: Include features like 'View_count', 'Like_count', 'Comment_count'
# Ensure these columns exist in your dataset
features = video_data[['Views', 'Likes', 'Comments']]

# Handle missing values if any
features.fillna(features.mean(), inplace=True)

# Standardize the features
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)
# Out:
# <ipython-input-45-c4e79edc3d35>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   features.fillna(features.mean(), inplace=True)

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Determine the number of clusters
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(features_scaled)
    wcss.append(kmeans.inertia_)

# Plot the Elbow Graph
plt.figure(figsize=(8, 5))
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method for Optimal Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Apply K-Means with the chosen number of clusters
kmeans = KMeans(n_clusters=4, init='k-means++', max_iter=300, n_init=10, random_state=0)
video_data['Cluster'] = kmeans.fit_predict(features_scaled)

# View the first few rows of the data with cluster assignments
print(video_data.head())
# Out:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             0           0
# 1             1           1
# 2             2           2
# 3             3           3
# 4             4           4
#
#                                                Title        Published_date  \
# 0  LOLLIPOP CHAINSAW REPOP Gameplay Walkthrough F...  2024-09-13T16:00:16Z
# 1  DEAD SPACE 2 Gameplay Walkthrough FULL GAME [4...  2024-09-12T19:03:11Z
# 2  SON AND BONE Gameplay Walkthrough FULL GAME [4...  2024-09-09T22:00:09Z
# 3  ASTRO BOT PS5 Gameplay Walkthrough FULL GAME 1...  2024-09-06T09:17:23Z
# 4  WARHAMMER 40K SPACE MARINE 2 Gameplay Walkthro...  2024-09-04T16:00:05Z
#
#     Views  Likes  Comments  Favourites Month  Cluster
# 0   38335   1141     153.0           0   Sep        1
# 1   23371    859      52.0           0   Sep        1
# 2  125263   2450     274.0           0   Sep        1
# 3  231978   4042     422.0           0   Sep        1
# 4  742945  12549    1205.0           0   Sep        0

# %%
# Analyze each cluster
for cluster in video_data['Cluster'].unique():
    segment = video_data[video_data['Cluster'] == cluster]
    print(f"\nCluster {cluster} statistics:")
    print(segment[['Views', 'Likes', 'Comments']].describe())
# Out:
# Cluster 1 statistics:
#               Views         Likes     Comments
# count  6.841000e+03   6841.000000  6840.000000
# mean   1.229992e+05   1360.500950   133.511404
# std    1.513698e+05   1651.981322   164.046690
# min    8.620000e+02      0.000000     0.000000
# 25%    3.256400e+04    319.000000    28.000000
# 50%    6.862000e+04    743.000000    70.000000
# 75%    1.456530e+05   1668.000000   174.000000
# max    1.717510e+06  10875.000000  1386.000000
#
# Cluster 0 statistics:
#               Views         Likes     Comments
# count  6.080000e+02    608.000000   608.000000
# mean   1.355165e+06  14333.898026  1112.618421
# std    7.342919e+05   6681.377521   644.250224
# min    1.740140e+05   2255.000000     0.000000
# 25%    8.299698e+05   9254.500000   653.500000
# 50%    1.182518e+06  12900.000000   945.500000
# 75%    1.703307e+06  18028.000000  1406.500000
# max    5.440975e+06  39871.000000  4213.000000
#
# Cluster 2 statistics:
#               Views          Likes      Comments
# count  1.080000e+02     108.000000    108.000000
# mean   4.390119e+06   45116.046296   3320.296296
# std    2.216346e+06   16752.250257   1996.574189
# min    3.057320e+05    6219.000000      0.000000
# 25%    2.961979e+06   34312.750000   2035.250000
# 50%    3.947500e+06   41354.000000   2673.500000
# 75%    5.289409e+06   53297.750000   4490.000000
# max    1.436080e+07  116377.000000  10946.000000
#
# Cluster 3 statistics:
#               Views          Likes      Comments
# count  1.100000e+01      11.000000     11.000000
# mean   1.362556e+07  138934.000000   9991.272727
# std    6.495086e+06   37398.528992   5420.243539
# min    8.056947e+06   98139.000000   3405.000000
# 25%    8.755602e+06  108943.000000   7120.500000
# 50%    1.063332e+07  138443.000000   8508.000000
# 75%    1.714114e+07  158253.500000  11623.500000
# max    2.811584e+07  223347.000000  23674.000000

# %%
# Define segments based on Views and Likes
def segment_video(row):
    if row['Views'] > 500000 and row['Likes'] > 10000:
        return 'High'
    elif row['Views'] > 100000 and row['Likes'] > 2000:
        return 'Medium'
    else:
        return 'Low'

video_data['Segment'] = video_data.apply(segment_video, axis=1)

# Display the segmented data
print(video_data[['Views', 'Likes', 'Segment']].head())
# Out:
#     Views  Likes Segment
# 0   38335   1141     Low
# 1   23371    859     Low
# 2  125263   2450  Medium
# 3  231978   4042  Medium
# 4  742945  12549    High

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Visualize the segments
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Views', y='Likes', hue='Segment', data=video_data, palette='coolwarm', s=100)
plt.title('Video Segmentation Based on Views and Likes')
plt.xlabel('Views')
plt.ylabel('Likes')
plt.legend(title='Segment')
plt.show()

# %%
# Plot a pie chart showing the distribution of segments
plt.figure(figsize=(8, 8))
segment_counts = video_data['Segment'].value_counts()
plt.pie(segment_counts, labels=segment_counts.index, autopct='%1.1f%%', colors=['#FF9999','#66B3FF','#99FF99'])
plt.title('Distribution of Video Segments')
plt.show()

# %%
# Box plot to compare views and likes across segments
plt.figure(figsize=(14, 7))
sns.boxplot(x='Segment', y='Views', data=video_data, palette='Set2')
plt.title('Distribution of Views by Segment')
plt.xlabel('Segment')
plt.ylabel('Views')
plt.show()

plt.figure(figsize=(14, 7))
sns.boxplot(x='Segment', y='Likes', data=video_data, palette='Set2')
plt.title('Distribution of Likes by Segment')
plt.xlabel('Segment')
plt.ylabel('Likes')
plt.show()
# Out:
# <ipython-input-53-dbbce2b3c3aa>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Segment', y='Views', data=video_data, palette='Set2')
# <ipython-input-53-dbbce2b3c3aa>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Segment', y='Likes', data=video_data, palette='Set2')

# %%
from sklearn.preprocessing import StandardScaler

# Extract relevant features
features = video_data[['Views', 'Likes']].dropna()

# Normalize the features
scaler = StandardScaler()
features_normalized = scaler.fit_transform(features)

# Display the normalized features
print(pd.DataFrame(features_normalized, columns=['Views', 'Likes']).head())
# Out:
#       Views     Likes
# 0 -0.294668 -0.238154
# 1 -0.311360 -0.270347
# 2 -0.197706 -0.088718
# 3 -0.078673  0.093024
# 4  0.491275  1.064182

# %%
from sklearn.cluster import KMeans

# Apply K-Means clustering
kmeans = KMeans(n_clusters=3, random_state=42)
video_data['Cluster'] = kmeans.fit_predict(features_normalized)

# Display the first few rows with cluster assignments
print(video_data[['Views', 'Likes', 'Cluster']].head())
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
#     Views  Likes  Cluster
# 0   38335   1141        0
# 1   23371    859        0
# 2  125263   2450        0
# 3  231978   4042        0
# 4  742945  12549        0

# %%
# Visualize the clustering
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Views', y='Likes', hue='Cluster', data=video_data, palette='viridis', s=100)
plt.title('K-Means Clustering of Videos Based on Views and Likes')
plt.xlabel('Views')
plt.ylabel('Likes')
plt.legend(title='Cluster')
plt.show()

# %%
# Calculate and display cluster centroids
centroids = kmeans.cluster_centers_
print("Cluster Centroids:\n", centroids)

# Display cluster sizes
cluster_sizes = video_data['Cluster'].value_counts()
print("Cluster Sizes:\n", cluster_sizes)
# Out:
# Cluster Centroids:
#  [[-0.15408894 -0.16114215]
#  [ 2.62501207  2.8042677 ]
#  [14.02147271 13.41481179]]
# Cluster Sizes:
#  Cluster
# 0    7215
# 1     337
# 2      16
# Name: count, dtype: int64

# %%
# Plot a pie chart showing the distribution of clusters
plt.figure(figsize=(8, 8))
cluster_counts = video_data['Cluster'].value_counts()
plt.pie(cluster_counts, labels=cluster_counts.index, autopct='%1.1f%%', colors=['#FF9999','#66B3FF','#99FF99'])
plt.title('Distribution of Video Clusters')
plt.show()

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# Calculate the sum of squared distances for different numbers of clusters
sse = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(features_normalized)
    sse.append(kmeans.inertia_)

# Plot the elbow curve
plt.figure(figsize=(8, 6))
plt.plot(range(1, 11), sse, marker='o', linestyle='--')
plt.title('Elbow Method for Optimal Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Sum of Squared Distances')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
